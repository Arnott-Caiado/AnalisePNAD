# %% [markdown]
# <a href="https://colab.research.google.com/github/Arnott-Caiado/AnalisePNAD/blob/master/PNADc_Tasks_tests_Arc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 
# Testes de visualizacoes de dados
#
